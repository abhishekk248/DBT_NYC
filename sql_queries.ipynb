# %%
import duckdb
import pandas as pd

# %%
sql_query='''
show tables
'''

with duckdb.connect('data/nyc_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#                               name
# 0   bronze_parking_violation_codes
# 1        bronze_parking_violations
# 2                      first_model
# 3              gold_ticket_metrics
# 4            gold_vehicles_metrics
# 5           parking_violation_2023
# 6          parking_violation_codes
# 7                        ref_model
# 8   silver_parking_violation_codes
# 9        silver_parking_violations
# 10        silver_violation_tickets
# 11       silver_violation_vehicles

# %%
sql1='''
CREATE OR REPLACE TABLE parking_violation_codes AS
SELECT * FROM read_csv_auto(
    'data/dof_parking_violation_codes.csv',
    normalize_names=True
)
'''

sql2='''
CREATE OR REPLACE TABLE parking_violation_2023 AS
SELECT * FROM read_csv_auto(
    'data/parking_violations_issued_fiscal_year_2023_sample.csv',
    normalize_names=True
)
'''

with duckdb.connect('data/nyc_violations.db') as con:
    con.sql(sql1)
    con.sql(sql2)

# %%
sql_query='''
select * from parking_violation_codes limit 10
'''

with duckdb.connect('data/nyc_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#    code                      definition  manhattan_96th_st_below  \
# 0     1   FAILURE TO DISPLAY BUS PERMIT                      515
# 1     2  NO OPERATOR NAM/ADD/PH DISPLAY                      515
# 2     3  UNAUTHORIZED PASSENGER PICK-UP                      515
# 3     4  BUS PARKING IN LOWER MANHATTAN                      115
# 4     5              BUS LANE VIOLATION                      250
# 5     6   OVERNIGHT TRACTOR TRAILER PKG                      500
# 6     7    FAILURE TO STOP AT RED LIGHT                       50
# 7     8                          IDLING                      115
# 8     9   OBSTRUCTING TRAFFIC/INTERSECT                      115
# 9    10     NO STOPPING-DAY/TIME LIMITS                      115
#
#    all_other_areas
# 0              515
# 1              515
# 2              515
# 3              115
# 4              250
# 5              500
# 6               50
# 7              115
# 8              115
# 9              115

# %%
sql_query='''
select * from bronze_parking_violation_codes limit 10
'''

with duckdb.connect('data/nyc_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#    violation_code                      definition  manhattan_96th_st_below  \
# 0               1   FAILURE TO DISPLAY BUS PERMIT                      515
# 1               2  NO OPERATOR NAM/ADD/PH DISPLAY                      515
# 2               3  UNAUTHORIZED PASSENGER PICK-UP                      515
# 3               4  BUS PARKING IN LOWER MANHATTAN                      115
# 4               5              BUS LANE VIOLATION                      250
# 5               6   OVERNIGHT TRACTOR TRAILER PKG                      500
# 6               7    FAILURE TO STOP AT RED LIGHT                       50
# 7               8                          IDLING                      115
# 8               9   OBSTRUCTING TRAFFIC/INTERSECT                      115
# 9              10     NO STOPPING-DAY/TIME LIMITS                      115
#
#    all_other_areas
# 0              515
# 1              515
# 2              515
# 3              115
# 4              250
# 5              500
# ...

# %%
sql_query='''
select * from bronze_parking_violations limit 10
'''

with duckdb.connect('data/nyc_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#    summons_number registration_state plate_type issue_date  violation_code  \
# 0      9010912681                 CA        PAS 2022-10-11              17
# 1      4858762841                 NY        PAS 2023-08-21              36
# 2      4854645684                 FL        PAS 2023-07-26              36
# 3      9044582707                 NY        PAS 2023-04-10              21
# 4      9041503330                 NY        PAS 2023-03-21              21
# 5      8964996320                 NY        COM 2023-06-12              21
# 6      9019285804                 NY        SRF 2022-11-20              40
# 7      9000744076                 CT        COM 2022-07-19              69
# 8      4839205334                 NY        PAS 2023-04-30              36
# 9      9006263692                 NY        PAS 2022-09-20              16
#
#   vehicle_body_type vehicle_make issuing_agency  vehicle_expiration_date  \
# ...

# %%
sql_query='''
select * from silver_parking_violation_codes limit 10
'''

with duckdb.connect('data/nyc_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#    violation_code                      definition  is_manhattan_96th_st_below  \
# 0               1   FAILURE TO DISPLAY BUS PERMIT                       False
# 1               1   FAILURE TO DISPLAY BUS PERMIT                        True
# 2               2  NO OPERATOR NAM/ADD/PH DISPLAY                       False
# 3               2  NO OPERATOR NAM/ADD/PH DISPLAY                        True
# 4               3  UNAUTHORIZED PASSENGER PICK-UP                       False
# 5               3  UNAUTHORIZED PASSENGER PICK-UP                        True
# 6               4  BUS PARKING IN LOWER MANHATTAN                       False
# 7               4  BUS PARKING IN LOWER MANHATTAN                        True
# 8               5              BUS LANE VIOLATION                       False
# 9               5              BUS LANE VIOLATION                        True
#
#    fee_usd
# 0      515
# 1      515
# 2      515
# 3      515
# 4      515
# 5      515
# 6      115
# ...

# %%
sql_query='''
select * from silver_parking_violations limit 20
'''

with duckdb.connect('data/nyc_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#     summons_number registration_state plate_type issue_date  violation_code  \
# 0       9010912681                 CA        PAS 2022-10-11              17
# 1       4858762841                 NY        PAS 2023-08-21              36
# 2       4854645684                 FL        PAS 2023-07-26              36
# 3       9044582707                 NY        PAS 2023-04-10              21
# 4       9041503330                 NY        PAS 2023-03-21              21
# 5       8964996320                 NY        COM 2023-06-12              21
# 6       9019285804                 NY        SRF 2022-11-20              40
# 7       9000744076                 CT        COM 2022-07-19              69
# 8       4839205334                 NY        PAS 2023-04-30              36
# 9       9006263692                 NY        PAS 2022-09-20              16
# 10      8849295534                 NY        COM 2022-09-12              21
# ...

# %%
sql_query='''
select * from silver_violation_tickets limit 10
'''

with duckdb.connect('data/nyc_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#    summons_number issue_date  violation_code  is_manhattan_96th_st_below  \
# 0      9010912681 2022-10-11              17                       False
# 1      4858762841 2023-08-21              36                       False
# 2      4854645684 2023-07-26              36                       False
# 3      9044582707 2023-04-10              21                       False
# 4      9041503330 2023-03-21              21                       False
# 5      8964996320 2023-06-12              21                       False
# 6      9019285804 2022-11-20              40                       False
# 7      9000744076 2022-07-19              69                       False
# 8      4839205334 2023-04-30              36                       False
# 9      9006263692 2022-09-20              16                       False
#
#    violation_location  violation_precinct  issuer_precinct issuer_command  \
# 0                50.0                  50               50           T201
# ...

# %%
sql_query='''
select * from silver_violation_vehicles limit 10
'''

with duckdb.connect('data/nyc_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#    summons_number registration_state plate_type vehicle_body_type  \
# 0      9010912681                 CA        PAS              SUBN
# 1      4858762841                 NY        PAS              4DSD
# 2      4854645684                 FL        PAS                UT
# 3      9044582707                 NY        PAS              SUBN
# 4      9041503330                 NY        PAS              4DSD
# 5      8964996320                 NY        COM               VAN
# 6      9019285804                 NY        SRF              SUBN
# 7      9000744076                 CT        COM              SUBN
# 8      4839205334                 NY        PAS              SUBN
# 9      9006263692                 NY        PAS              SUBN
#
#   vehicle_make  vehicle_expiration_date vehicle_color  vehicle_year
# 0         FORD                 20220788         BLACK             0
# 1        HONDA                        0            GY          2003
# ...

# %%
sql_query='''
select * from gold_ticket_metrics limit 10
'''

with duckdb.connect('data/nyc_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#    violation_code  ticket_count  total_revenue_usd
# 0              36         37064          1853200.0
# 1               5          3477           869250.0
# 2              21         12149           789685.0
# 3              14          5047           580405.0
# 4              40          3902           448730.0
# 5              71          3655           237575.0
# 6              20          3949           236940.0
# 7              46          2051           235865.0
# 8              38          6482           226870.0
# 9               7          4055           202750.0

# %%
sql_query='''
select * from gold_vehicles_metrics limit 10
'''

with duckdb.connect('data/nyc_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#   registration_state  ticket_count
# 0                 NJ          9258
# 1                 PA          3514
# 2                 FL          2414
# 3                 CT          1787
# 4                 GA           840
# 5                 VA           797
# 6                 MA           788
# 7                 IN           765
# 8                 NC           614
# 9                 TX           594

# %%
sql_query='''
select * from "nyc_violations"."main_dbt_test__audit"."violation_codes_revenue"
'''

with duckdb.connect('data/nyc_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#    violation_code  total_revenue_usd
# 0              41                0.0

# %%
sql1='''
CREATE OR REPLACE TABLE parking_violation_codes AS
SELECT * FROM read_csv_auto(
    'data/dof_parking_violation_codes.csv',
    normalize_names=True
)
'''

sql2='''
CREATE OR REPLACE TABLE parking_violation_2023 AS
SELECT * FROM read_csv_auto(
    'data/parking_violations_issued_fiscal_year_2023_sample.csv',
    normalize_names=True
)
'''

with duckdb.connect('data/prod_nyc_violations.db') as con:
    con.sql(sql1)
    con.sql(sql2)
